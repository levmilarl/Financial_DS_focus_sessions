# %%
import numpy as np
import pandas as pd

# %%
df_spx = pd.read_parquet("data/spx_ivs_2023-02.parquet")

# %%
def calculate_V(df_one_day, variables): #df_one_day only contains data from one day. variables is a list of needed ... todo save it as a vector

    # underlying price at time t
    S_t = variables[0]

    # strike price
    K = variables[1]

    # call price C(t, tau, K) depending of an underlying asset with price S(t), date to maturity tau, strike price K
    C = variables[2]

    # put price C(t, tau, K) depending of an underlying asset with price S(t), date to maturity tau, strike price K
    P = variables[3]

    # formula for integrand in integral from S_t to infinity
    puts = (2 * (1 + np.log(S_t / K)) / np.square(K) * P).dropna()

    # formula for integrand in integral from S_t to infinity
    calls = (2 * (1 - np.log(K / S_t)) / np.square(K) * C).dropna()

    x = K.copy()

    # concat works as dataset is sorted in a way that puts come before calls.
    y = pd.concat([puts, calls]).copy()

    #return trap_integral(y,x)
    return np.trapezoid(y,x)

# %%
def calculate_W(df_one_day, variables):

    S_t = variables[0]
    K = variables[1]
    C = variables[2]
    P = variables[3]

    # formula for integrand in integral from S_t to infinity
    puts = ((6 * np.log(S_t / K) + 3 * (np.log(S_t / K)) ** 2 ) / (K ** 2) * P).dropna()

    calls = (( 6 * np.log(K / S_t) - 3 * (np.log(K / S_t)) ** 2) / (K ** 2) * C).dropna()


    puts_integral = np.trapezoid(puts, K[df_one_day["putcall"] == "P"])
    calls_integral = np.trapezoid(calls, K[df_one_day["putcall"] == "C"])


    return calls_integral - puts_integral

# %%
def calculate_X(df_one_day, variables):
    S_t = variables[0]
    K = variables[1]
    C = variables[2]
    P = variables[3]

    # formula for integrand in integral from S_t to infinity
    puts = ((12 * np.log(S_t / K) ** 2 + 4 * np.log(S_t / K) ** 3) / (K ** 2) * P).dropna()

    calls = ((12 * np.log(K / S_t) ** 2 - 4 * np.log(K / S_t) ** 3 ) / (K ** 2) * C).dropna()

    puts_integral = np.trapezoid(puts, K[df_one_day["putcall"] == "P"])
    calls_integral = np.trapezoid(calls, K[df_one_day["putcall"] == "C"])

    return calls_integral + puts_integral

# %%
def calculate_mu(df_one_day, e_rt, variables):
    return e_rt - 1 - e_rt / 2 * calculate_V(df_one_day, variables) - e_rt / 6 * calculate_W(df_one_day, variables) - e_rt / 24 * calculate_X(df_one_day, variables)

# %%
df_riskfree_yields = pd.read_csv("data/riskfree_30d_2023-02.csv")

df_riskfree_yields['exp_rt'] = np.exp((df_riskfree_yields['yld_pct_annual'] / 100) * (df_riskfree_yields['daystomaturity'] / 365))

#calculate_mu(next(iter(df.groupby("loctimestamp")))[1], df_riskfree_yields['exp_rt'].iloc[0])

# %% [markdown]
# #Calculate the first four moments for SPX:

# %%
def calculate_first_four_moments(df, df_riskfree_yields):
    rows = []
    min_days = 5
    #check for at least min_days of data
    if df.groupby('loctimestamp').ngroups < min_days:
        print("Not enough data for calculating first four moments.")
        return pd.DataFrame()
    for timestamp, df_day in df.groupby('loctimestamp'):
        #print("calculating day ", timestamp)

        # underlying price at time t
        S_t = df_day["underlyingprice"].copy()

        # strike price
        K = df_day["strike"].copy()

        # call price C(t, tau, K) depending of an underlying asset with price S(t), date to maturity tau, strike price K
        C = df_day[df_day["putcall"] == "C"]["implPrice"].copy()

        # put price C(t, tau, K) depending of an underlying asset with price S(t), date to maturity tau, strike price K
        P = df_day[df_day["putcall"] == "P"]["implPrice"].copy()

        variables = [S_t, K, C, P]

        e_rt = df_riskfree_yields[df_riskfree_yields['date'] == timestamp.strftime("%Y-%m-%d")]["exp_rt"].iloc[0]

        V = calculate_V(df_day, variables)
        W = calculate_W(df_day, variables)
        X = calculate_X(df_day, variables)

        # calculate first four moments:
        mu = calculate_mu(df_day, e_rt, variables)
        impl_Var = calculate_V(df_day, variables) * e_rt - calculate_mu(df_day, e_rt, variables) ** 2
        skew = (e_rt * W - 3*mu*e_rt*V + 2*mu**3) / ((e_rt*V - mu**2) ** (3 / 2))
        kurt = (e_rt*X - 4*mu*e_rt*W + 6*e_rt*mu**2*V -3*mu**4) / ((e_rt*V - mu**2)**2)

        rows.append({
            "loctimestamp": timestamp,
            "mu": mu,
            "impl_Var": impl_Var,
            "skew": skew,
            "kurt": kurt
        })

    return pd.DataFrame(rows)

# %%
calculate_first_four_moments(df_spx, df_riskfree_yields)
# Out:
#    loctimestamp        mu  impl_Var      skew       kurt
# 0    2023-02-01  0.002449  0.002886 -1.890367  13.690297
# 1    2023-02-02  0.002273  0.003315 -1.920767  14.008410
# 2    2023-02-03  0.002444  0.002812 -1.956828  14.071976
# 3    2023-02-06  0.002251  0.003310 -1.856700  13.430530
# 4    2023-02-07  0.002434  0.002927 -1.914680  14.255292
# 5    2023-02-08  0.002297  0.003261 -1.958047  14.242735
# 6    2023-02-09  0.002095  0.003718 -1.935017  13.924228
# 7    2023-02-10  0.002206  0.003433 -1.946166  14.288918
# 8    2023-02-13  0.002034  0.003885 -1.857297  13.722240
# 9    2023-02-14  0.002452  0.002883 -1.966343  14.373541
# 10   2023-02-15  0.002532  0.002745 -1.960125  14.308666
# 11   2023-02-16  0.002361  0.003235 -2.245477  16.058125
# 12   2023-02-17  0.002417  0.002971 -2.100606  14.901896
# 13   2023-02-21  0.001847  0.004200 -2.105463  15.486245
# 14   2023-02-22  0.001899  0.004051 -2.140100  15.691399
# 15   2023-02-23  0.002277  0.003420 -1.943272  14.015983
# 16   2023-02-24  0.002188  0.003533 -1.960625  14.880790
# 17   2023-02-27  0.002256  0.003564 -1.890661  14.642610
# 18   2023-02-28  0.002341  0.003363 -1.811390  14.142479

# %%
df_sp500 = pd.read_parquet("data/sp500_merged_ivs_2023-02.parquet")
for ticker, df_ticker in df_sp500.groupby("Symbol"):
    print(f"calculating for ticker {ticker}")

    # filter days with NaN values in important columns
    bad_days = df_ticker.groupby('loctimestamp').filter(
        lambda x: x[['strike', 'underlyingprice', 'implPrice']].isna().any().any()
    )['loctimestamp'].unique()

    # Remove all rows for those bad days
    df_clean = df_ticker[~df_ticker['loctimestamp'].isin(bad_days)]

    calculate_first_four_moments(df_clean, df_riskfree_yields) #.to_csv(f"data/sp500_moments/{ticker}_first_four_moments.csv", index=False)
# Out:
# calculating for ticker A
# calculating for ticker AAL
# calculating for ticker AAP
# calculating for ticker AAPL
# calculating for ticker ABBV
# calculating for ticker ABC
# calculating for ticker ABT
# calculating for ticker ACGL
# calculating for ticker ACN
# calculating for ticker ADBE
# calculating for ticker ADI
# calculating for ticker ADM
# calculating for ticker ADP
# calculating for ticker ADSK
# calculating for ticker AEE
# calculating for ticker AEP
# calculating for ticker AES
# calculating for ticker AFL
# calculating for ticker AIG
# calculating for ticker AIZ
# calculating for ticker AJG
# calculating for ticker AKAM
# calculating for ticker ALB
# calculating for ticker ALGN
# calculating for ticker ALK
# calculating for ticker ALL
# calculating for ticker ALLE
# calculating for ticker AMAT
# calculating for ticker AMCR
# calculating for ticker AMD
# calculating for ticker AME
# calculating for ticker AMGN
# calculating for ticker AMP
# calculating for ticker AMT
# calculating for ticker AMZN
# calculating for ticker ANET
# calculating for ticker ANSS
# calculating for ticker AON
# calculating for ticker AOS
# calculating for ticker APA
# calculating for ticker APD
# calculating for ticker APH
# calculating for ticker APTV
# calculating for ticker ARE
# calculating for ticker ATO
# calculating for ticker ATVI
# calculating for ticker AVB
# calculating for ticker AVGO
# calculating for ticker AVY
# calculating for ticker AWK
# calculating for ticker AXP
# calculating for ticker AZO
# calculating for ticker BA
# calculating for ticker BAC
# calculating for ticker BALL
# calculating for ticker BAX
# calculating for ticker BBWI
# calculating for ticker BBY
# calculating for ticker BDX
# calculating for ticker BEN
# calculating for ticker BF.B
# calculating for ticker BIIB
# calculating for ticker BIO
# C:\Users\I745460\AppData\Local\Temp\ipykernel_41788\1207656753.py:34: RuntimeWarning: invalid value encountered in scalar power
#   skew = (e_rt * W - 3*mu*e_rt*V + 2*mu**3) / ((e_rt*V - mu**2) ** (3 / 2))
# calculating for ticker BK
# calculating for ticker BKNG
# calculating for ticker BKR
# calculating for ticker BLK
# calculating for ticker BMY
# calculating for ticker BR
# calculating for ticker BRK.B
# calculating for ticker BRO
# calculating for ticker BSX
# calculating for ticker BWA
# calculating for ticker BXP
# calculating for ticker C
# calculating for ticker CAG
# calculating for ticker CAH
# calculating for ticker CARR
# calculating for ticker CAT
# calculating for ticker CB
# calculating for ticker CBOE
# calculating for ticker CBRE
# calculating for ticker CCI
# calculating for ticker CCL
# calculating for ticker CDAY
# calculating for ticker CDNS
# calculating for ticker CDW
# calculating for ticker CE
# calculating for ticker CEG
# calculating for ticker CF
# calculating for ticker CFG
# calculating for ticker CHD
# calculating for ticker CHRW
# calculating for ticker CHTR
# calculating for ticker CI
# calculating for ticker CINF
# calculating for ticker CL
# calculating for ticker CLX
# calculating for ticker CMA
# calculating for ticker CMCSA
# calculating for ticker CME
# calculating for ticker CMG
# calculating for ticker CMI
# calculating for ticker CMS
# calculating for ticker CNC
# calculating for ticker CNP
# calculating for ticker COF
# calculating for ticker COP
# calculating for ticker COST
# calculating for ticker CPB
# calculating for ticker CPRT
# calculating for ticker CPT
# calculating for ticker CRL
# calculating for ticker CRM
# calculating for ticker CSCO
# calculating for ticker CSGP
# calculating for ticker CSX
# calculating for ticker CTAS
# calculating for ticker CTLT
# calculating for ticker CTRA
# calculating for ticker CTSH
# calculating for ticker CTVA
# calculating for ticker CVS
# calculating for ticker CVX
# calculating for ticker CZR
# calculating for ticker D
# calculating for ticker DAL
# calculating for ticker DD
# calculating for ticker DE
# calculating for ticker DFS
# calculating for ticker DG
# calculating for ticker DGX
# calculating for ticker DHI
# calculating for ticker DHR
# calculating for ticker DIS
# calculating for ticker DISH
# calculating for ticker DLR
# calculating for ticker DLTR
# calculating for ticker DOV
# calculating for ticker DOW
# calculating for ticker DPZ
# calculating for ticker DRI
# calculating for ticker DTE
# calculating for ticker DUK
# calculating for ticker DVA
# calculating for ticker DVN
# calculating for ticker DXC
# calculating for ticker DXCM
# calculating for ticker EA
# calculating for ticker EBAY
# calculating for ticker ECL
# calculating for ticker ED
# calculating for ticker EFX
# calculating for ticker EIX
# calculating for ticker EL
# calculating for ticker ELV
# calculating for ticker EMN
# calculating for ticker EMR
# calculating for ticker ENPH
# calculating for ticker EOG
# calculating for ticker EPAM
# calculating for ticker EQIX
# calculating for ticker EQR
# calculating for ticker EQT
# calculating for ticker ES
# calculating for ticker ESS
# calculating for ticker ETN
# calculating for ticker ETR
# calculating for ticker ETSY
# calculating for ticker EVRG
# calculating for ticker EW
# calculating for ticker EXC
# calculating for ticker EXPD
# calculating for ticker EXPE
# calculating for ticker EXR
# calculating for ticker F
# calculating for ticker FANG
# calculating for ticker FAST
# calculating for ticker FCX
# calculating for ticker FDS
# calculating for ticker FDX
# calculating for ticker FE
# calculating for ticker FFIV
# calculating for ticker FIS
# calculating for ticker FISV
# calculating for ticker FITB
# calculating for ticker FLT
# calculating for ticker FMC
# calculating for ticker FOX
# calculating for ticker FOXA
# calculating for ticker FRC
# calculating for ticker FRT
# calculating for ticker FSLR
# calculating for ticker FTNT
# calculating for ticker FTV
# calculating for ticker GD
# calculating for ticker GE
# calculating for ticker GEHC
# calculating for ticker GEN
# calculating for ticker GILD
# calculating for ticker GIS
# calculating for ticker GL
# calculating for ticker GLW
# calculating for ticker GM
# calculating for ticker GNRC
# calculating for ticker GOOG
# calculating for ticker GOOGL
# calculating for ticker GPC
# calculating for ticker GPN
# calculating for ticker GRMN
# calculating for ticker GS
# calculating for ticker GWW
# calculating for ticker HAL
# calculating for ticker HAS
# calculating for ticker HBAN
# calculating for ticker HCA
# calculating for ticker HD
# calculating for ticker HES
# calculating for ticker HIG
# calculating for ticker HII
# calculating for ticker HLT
# calculating for ticker HOLX
# calculating for ticker HON
# calculating for ticker HPE
# calculating for ticker HPQ
# calculating for ticker HRL
# calculating for ticker HSIC
# calculating for ticker HST
# calculating for ticker HSY
# calculating for ticker HUM
# calculating for ticker HWM
# calculating for ticker IBM
# calculating for ticker ICE
# calculating for ticker IDXX
# calculating for ticker IEX
# calculating for ticker IFF
# calculating for ticker ILMN
# calculating for ticker INCY
# calculating for ticker INTC
# calculating for ticker INTU
# calculating for ticker INVH
# calculating for ticker IP
# calculating for ticker IPG
# calculating for ticker IQV
# calculating for ticker IR
# calculating for ticker IRM
# calculating for ticker ISRG
# calculating for ticker IT
# calculating for ticker ITW
# calculating for ticker IVZ
# calculating for ticker J
# calculating for ticker JBHT
# calculating for ticker JCI
# calculating for ticker JKHY
# calculating for ticker JNJ
# calculating for ticker JNPR
# calculating for ticker JPM
# calculating for ticker K
# calculating for ticker KDP
# calculating for ticker KEY
# calculating for ticker KEYS
# calculating for ticker KHC
# calculating for ticker KIM
# calculating for ticker KLAC
# calculating for ticker KMB
# calculating for ticker KMI
# calculating for ticker KMX
# calculating for ticker KO
# calculating for ticker KR
# calculating for ticker L
# calculating for ticker LDOS
# calculating for ticker LEN
# calculating for ticker LH
# calculating for ticker LHX
# calculating for ticker LIN
# calculating for ticker LKQ
# calculating for ticker LLY
# calculating for ticker LMT
# calculating for ticker LNC
# calculating for ticker LNT
# calculating for ticker LOW
# calculating for ticker LRCX
# calculating for ticker LUMN
# calculating for ticker LUV
# calculating for ticker LVS
# calculating for ticker LW
# calculating for ticker LYB
# calculating for ticker LYV
# calculating for ticker MA
# calculating for ticker MAA
# calculating for ticker MAR
# calculating for ticker MAS
# calculating for ticker MCD
# calculating for ticker MCHP
# calculating for ticker MCK
# calculating for ticker MCO
# calculating for ticker MDLZ
# calculating for ticker MDT
# calculating for ticker MET
# calculating for ticker META
# calculating for ticker MGM
# calculating for ticker MHK
# calculating for ticker MKC
# calculating for ticker MKTX
# calculating for ticker MLM
# calculating for ticker MMC
# calculating for ticker MMM
# calculating for ticker MNST
# calculating for ticker MO
# calculating for ticker MOH
# calculating for ticker MOS
# calculating for ticker MPC
# calculating for ticker MPWR
# calculating for ticker MRK
# calculating for ticker MRNA
# calculating for ticker MRO
# calculating for ticker MS
# calculating for ticker MSCI
# calculating for ticker MSFT
# calculating for ticker MSI
# calculating for ticker MTB
# calculating for ticker MTCH
# calculating for ticker MTD
# calculating for ticker MU
# calculating for ticker NCLH
# calculating for ticker NDAQ
# calculating for ticker NDSN
# calculating for ticker NEE
# calculating for ticker NEM
# calculating for ticker NFLX
# calculating for ticker NI
# calculating for ticker NKE
# calculating for ticker NOC
# calculating for ticker NOW
# calculating for ticker NRG
# calculating for ticker NSC
# calculating for ticker NTAP
# calculating for ticker NTRS
# calculating for ticker NUE
# calculating for ticker NVDA
# calculating for ticker NWL
# calculating for ticker NWSA
# calculating for ticker NXPI
# calculating for ticker O
# calculating for ticker ODFL
# calculating for ticker OGN
# calculating for ticker OKE
# calculating for ticker OMC
# calculating for ticker ON
# calculating for ticker ORCL
# calculating for ticker ORLY
# calculating for ticker OTIS
# calculating for ticker OXY
# calculating for ticker PARA
# calculating for ticker PAYC
# calculating for ticker PAYX
# calculating for ticker PCAR
# calculating for ticker PCG
# calculating for ticker PEAK
# calculating for ticker PEG
# calculating for ticker PEP
# calculating for ticker PFE
# calculating for ticker PFG
# calculating for ticker PG
# calculating for ticker PGR
# calculating for ticker PH
# calculating for ticker PHM
# calculating for ticker PKG
# calculating for ticker PKI
# calculating for ticker PLD
# calculating for ticker PM
# calculating for ticker PNC
# calculating for ticker PNR
# calculating for ticker PNW
# calculating for ticker POOL
# calculating for ticker PPG
# calculating for ticker PPL
# calculating for ticker PRU
# calculating for ticker PSA
# calculating for ticker PSX
# calculating for ticker PTC
# calculating for ticker PWR
# calculating for ticker PXD
# calculating for ticker PYPL
# calculating for ticker QCOM
# calculating for ticker QRVO
# calculating for ticker RCL
# calculating for ticker RE
# calculating for ticker REG
# calculating for ticker REGN
# calculating for ticker RF
# calculating for ticker RHI
# calculating for ticker RJF
# calculating for ticker RL
# calculating for ticker RMD
# calculating for ticker ROK
# calculating for ticker ROL
# calculating for ticker ROP
# calculating for ticker ROST
# calculating for ticker RSG
# calculating for ticker RTX
# calculating for ticker SBAC
# calculating for ticker SBNY
# calculating for ticker SBUX
# calculating for ticker SCHW
# calculating for ticker SEDG
# calculating for ticker SEE
# calculating for ticker SHW
# calculating for ticker SIVB
# calculating for ticker SJM
# calculating for ticker SLB
# calculating for ticker SNA
# calculating for ticker SNPS
# calculating for ticker SO
# calculating for ticker SPG
# calculating for ticker SPGI
# calculating for ticker SRE
# calculating for ticker STE
# calculating for ticker STLD
# calculating for ticker STT
# calculating for ticker STX
# calculating for ticker STZ
# calculating for ticker SWK
# calculating for ticker SWKS
# calculating for ticker SYF
# calculating for ticker SYK
# calculating for ticker SYY
# calculating for ticker T
# calculating for ticker TAP
# calculating for ticker TDG
# calculating for ticker TDY
# calculating for ticker TECH
# calculating for ticker TEL
# calculating for ticker TER
# calculating for ticker TFC
# calculating for ticker TFX
# calculating for ticker TGT
# calculating for ticker TJX
# calculating for ticker TMO
# calculating for ticker TMUS
# calculating for ticker TPR
# calculating for ticker TRGP
# calculating for ticker TRMB
# calculating for ticker TROW
# calculating for ticker TRV
# calculating for ticker TSCO
# calculating for ticker TSLA
# calculating for ticker TSN
# calculating for ticker TT
# calculating for ticker TTWO
# calculating for ticker TXN
# calculating for ticker TXT
# calculating for ticker TYL
# calculating for ticker UAL
# calculating for ticker UDR
# calculating for ticker UHS
# calculating for ticker ULTA
# calculating for ticker UNH
# calculating for ticker UNP
# calculating for ticker UPS
# calculating for ticker URI
# calculating for ticker USB
# calculating for ticker V
# calculating for ticker VFC
# calculating for ticker VICI
# calculating for ticker VLO
# calculating for ticker VMC
# calculating for ticker VRSK
# calculating for ticker VRSN
# calculating for ticker VRTX
# calculating for ticker VTR
# calculating for ticker VTRS
# calculating for ticker VZ
# calculating for ticker WAB
# calculating for ticker WAT
# calculating for ticker WBA
# calculating for ticker WBD
# calculating for ticker WDC
# calculating for ticker WEC
# calculating for ticker WELL
# calculating for ticker WFC
# calculating for ticker WHR
# calculating for ticker WM
# calculating for ticker WMB
# calculating for ticker WMT
# calculating for ticker WRB
# calculating for ticker WRK
# calculating for ticker WST
# calculating for ticker WTW
# calculating for ticker WY
# calculating for ticker WYNN
# calculating for ticker XEL
# calculating for ticker XOM
# calculating for ticker XRAY
# calculating for ticker XYL
# calculating for ticker YUM
# calculating for ticker ZBH
# calculating for ticker ZBRA
# calculating for ticker ZION
# calculating for ticker ZTS

# %%
# Out:
# calculating day  2023-02-22 00:00:00
# KeyboardInterrupt
