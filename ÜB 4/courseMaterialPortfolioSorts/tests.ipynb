# %%
import pandas as pd
df = pd.read_parquet("PortfoliosOutcomePlusDiff_arne.parquet")
df
# Out:
#           date  bakshi_mu_tau_30_1_bakshiSkew_tau_30_1  \
# 0   2005-01-03                                0.014557
# 1   2005-02-01                                0.064044
# 2   2005-03-01                               -0.047904
# 3   2005-04-01                               -0.006244
# 4   2005-05-02                                0.055101
# ..         ...                                     ...
# 211 2022-08-01                               -0.021591
# 212 2022-09-01                               -0.056777
# 213 2022-10-03                               -0.030545
# 214 2022-11-01                               -0.093573
# 215 2022-12-01                               -0.073114
#
#      bakshi_mu_tau_30_1_bakshiSkew_tau_30_2  \
# 0                                 -0.097570
# 1                                  0.017657
# 2                                 -0.050101
# 3                                 -0.057019
# 4                                  0.116600
# ...

# %%
df2 = pd.read_parquet("solution/PortfoliosOutcomePlusDiffTest.parquet")
df2
# Out:
#                                          Average    StdErr    t-stat   p-value
# bakshi_mu_tau_30_1_bakshiSkew_tau_30_1  0.001200  0.006176  0.147274  0.882916
# bakshi_mu_tau_30_1_bakshiSkew_tau_30_2  0.008370  0.006157  1.323490  0.185673
# bakshi_mu_tau_30_1_bakshiSkew_tau_30_3  0.008362  0.006295  1.215040  0.224351
# bakshi_mu_tau_30_1_bakshiSkew_tau_30_4  0.004236  0.007185  0.577239  0.563778
# bakshi_mu_tau_30_2_bakshiSkew_tau_30_1  0.004739  0.004283  1.126594  0.259914
# bakshi_mu_tau_30_2_bakshiSkew_tau_30_2  0.004225  0.004539  0.919257  0.357961
# bakshi_mu_tau_30_2_bakshiSkew_tau_30_3  0.006581  0.004586  1.482076  0.138320
# bakshi_mu_tau_30_2_bakshiSkew_tau_30_4  0.007370  0.004445  1.761637  0.078131
# bakshi_mu_tau_30_3_bakshiSkew_tau_30_1  0.006105  0.003747  1.513431  0.130170
# bakshi_mu_tau_30_3_bakshiSkew_tau_30_2  0.007569  0.003830  2.128137  0.033326
# bakshi_mu_tau_30_3_bakshiSkew_tau_30_3  0.007775  0.003681  2.217158  0.026612
# ...

# %%
df2
# Out:
#           date  bakshi_mu_tau_30_1_bakshiSkew_tau_30_1  \
# 0   2005-01-03                                0.014557
# 1   2005-02-01                                0.064044
# 2   2005-03-01                               -0.047904
# 3   2005-04-01                               -0.006244
# 4   2005-05-02                                0.055101
# ..         ...                                     ...
# 211 2022-08-01                               -0.021591
# 212 2022-09-01                               -0.056777
# 213 2022-10-03                               -0.030545
# 214 2022-11-01                               -0.093573
# 215 2022-12-01                               -0.073114
#
#      bakshi_mu_tau_30_1_bakshiSkew_tau_30_2  \
# 0                                 -0.097570
# 1                                  0.017657
# 2                                 -0.050101
# 3                                 -0.057019
# 4                                  0.116600
# ...
